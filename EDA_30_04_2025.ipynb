# %%
# #Exploratory Data Analysis:It is a crucial initial step in Data analysis
# # aimed at summarizing the main charcterstics of the data
# #It aims using pandas library
# # Steps of EDA
# Dataunderstanding,univariate analysis,Bivariate and Multivariate analysis
# Feature engineering and Data cleaning
# UNIVARIATE:UNDERSTAND THEIR DISTRIBUTION AND IDENTIFY OUTLIERS
# Bivariate and Multivariate Analysis:Exploring relationship between pairs or 
##group of variables using corelation and different data visualization
import pandas as pd
df=pd.read_csv(r"C:\Users\GT-499\Downloads\students.csv")
df
# Out:
#                Name  Grade  Test Score Attendance  Assignment Score  \
# 0     Alice Johnson     10        92.5        95%              88.2
# 1         Bob Smith      8        78.3        90%              75.6
# 2   Catherine Brown     11        88.9        92%              90.1
# 3      David Miller      9        85.2        88%              82.3
# 4        Emma Davis     12        95.7        98%              94.5
# 5      Frank Wilson      7        72.8        85%              68.7
# 6      Grace Taylor     10        91.4        93%              89.8
# 7       Henry Jones      8        79.6        87%              76.4
# 8      Isabel White     11        87.1        91%              85.9
# 9    James Anderson      9        84.3        89%              81.7
# 10    Alice Johnson     10        92.5        95%              88.2
# 11        Bob Smith      8        78.3        90%              75.6
# 12  Catherine Brown     11        88.9        92%              90.1
# ...

# %%
df.shape
# Out:
# (20, 10)

# %%
df.columns
# Out:
# Index(['Name', 'Grade', 'Test Score', 'Attendance', 'Assignment Score',
#        'Participation', 'Project Score', 'Lab Score', 'Final Exam',
#        'Total Score'],
#       dtype='object')

# %%
df.describe()
# ENTIRE STATISTICS OF THE DATASET
# Out:
#            Grade  Test Score  Assignment Score  Project Score  Final Exam  \
# count  20.000000   20.000000         20.000000      20.000000   20.000000
# mean    9.500000   85.580000         83.320000      85.710000   85.080000
# std     1.538968    6.892987          7.734516       5.998675    6.098973
# min     7.000000   72.800000         68.700000      75.100000   76.300000
# 25%     8.000000   79.600000         76.400000      80.200000   79.800000
# 50%     9.500000   86.150000         84.100000      86.450000   84.850000
# 75%    11.000000   91.400000         89.800000      91.500000   88.700000
# max    12.000000   95.700000         94.500000      93.200000   96.400000
#
#        Total Score
# count    20.000000
# mean     85.020000
# std       6.575521
# min      74.200000
# 25%      78.700000
# 50%      85.850000
# 75%      89.600000
# max      95.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              20 non-null     object
#  1   Grade             20 non-null     int64
#  2   Test Score        20 non-null     float64
#  3   Attendance        20 non-null     object
#  4   Assignment Score  20 non-null     float64
#  5   Participation     20 non-null     object
#  6   Project Score     20 non-null     float64
#  7   Lab Score         20 non-null     object
#  8   Final Exam        20 non-null     float64
#  9   Total Score       20 non-null     float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.7+ KB

# %%
df.head()
# The first five rows read
# Out:
#               Name  Grade  Test Score Attendance  Assignment Score  \
# 0    Alice Johnson     10        92.5        95%              88.2
# 1        Bob Smith      8        78.3        90%              75.6
# 2  Catherine Brown     11        88.9        92%              90.1
# 3     David Miller      9        85.2        88%              82.3
# 4       Emma Davis     12        95.7        98%              94.5
#
#   Participation  Project Score Lab Score  Final Exam  Total Score
# 0           90%           85.6       94%        91.8         89.4
# 1           88%           79.2       82%        78.4         77.1
# 2           94%           92.7       89%        87.5         89.6
# 3           91%           88.9       85%        83.6         84.2
# 4           96%           93.2       97%        96.4         95.8

# %%
df.tail()
# Out:
#               Name  Grade  Test Score Attendance  Assignment Score  \
# 15    Frank Wilson      7        72.8        85%              68.7
# 16    Grace Taylor     10        91.4        93%              89.8
# 17     Henry Jones      8        79.6        87%              76.4
# 18    Isabel White     11        87.1        91%              85.9
# 19  James Anderson      9        84.3        89%              81.7
#
#    Participation  Project Score Lab Score  Final Exam  Total Score
# 15           80%           75.1       78%        76.3         74.2
# 16           92%           91.5       90%        88.7         90.1
# 17           85%           80.2       81%        79.8         78.7
# 18           89%           87.3       88%        86.1         87.5
# 19           86%           83.4       84%        82.2         83.6

# %%
df.head(11)
# ZERO TO HEAD
# Out:
#                Name  Grade  Test Score Attendance  Assignment Score  \
# 0     Alice Johnson     10        92.5        95%              88.2
# 1         Bob Smith      8        78.3        90%              75.6
# 2   Catherine Brown     11        88.9        92%              90.1
# 3      David Miller      9        85.2        88%              82.3
# 4        Emma Davis     12        95.7        98%              94.5
# 5      Frank Wilson      7        72.8        85%              68.7
# 6      Grace Taylor     10        91.4        93%              89.8
# 7       Henry Jones      8        79.6        87%              76.4
# 8      Isabel White     11        87.1        91%              85.9
# 9    James Anderson      9        84.3        89%              81.7
# 10    Alice Johnson     10        92.5        95%              88.2
#
#    Participation  Project Score Lab Score  Final Exam  Total Score
# 0            90%           85.6       94%        91.8         89.4
# ...

# %%
df.isnull()
# Out:
#      Name  Grade  Test Score  Attendance  Assignment Score  Participation  \
# 0   False  False       False       False             False          False
# 1   False  False       False       False             False          False
# 2   False  False       False       False             False          False
# 3   False  False       False       False             False          False
# 4   False  False       False       False             False          False
# 5   False  False       False       False             False          False
# 6   False  False       False       False             False          False
# 7   False  False       False       False             False          False
# 8   False  False       False       False             False          False
# 9   False  False       False       False             False          False
# 10  False  False       False       False             False          False
# 11  False  False       False       False             False          False
# ...

# %%
df.isnull().sum()
# Out:
# Name                0
# Grade               0
# Test Score          0
# Attendance          0
# Assignment Score    0
# Participation       0
# Project Score       0
# Lab Score           0
# Final Exam          0
# Total Score         0
# dtype: int64

# %%
df.nunique()
# Out:
# Name                10
# Grade                6
# Test Score          10
# Attendance          10
# Assignment Score    10
# Participation       10
# Project Score       10
# Lab Score           10
# Final Exam          10
# Total Score         10
# dtype: int64

# %%
df['Grade'].unique()
# Out:
# array([10,  8, 11,  9, 12,  7], dtype=int64)

# %%
# TEST SCORE AND ASSIGNMENT SCORE

# %%
#type(10)
# Out:
# int

# %%
df['Test Score'].unique()
# Out:
# array([92.5, 78.3, 88.9, 85.2, 95.7, 72.8, 91.4, 79.6, 87.1, 84.3])

# %%
#

# %%
z=df.corr(numeric_only=True)

# %%
z
# Out:
#                      Grade  Test Score  Assignment Score  Project Score  \
# Grade             1.000000    0.908940          0.950654       0.895649
# Test Score        0.908940    1.000000          0.983142       0.896207
# Assignment Score  0.950654    0.983142          1.000000       0.944275
# Project Score     0.895649    0.896207          0.944275       1.000000
# Final Exam        0.905032    0.972444          0.947236       0.837864
# Total Score       0.954903    0.984246          0.990294       0.927296
#
#                   Final Exam  Total Score
# Grade               0.905032     0.954903
# Test Score          0.972444     0.984246
# Assignment Score    0.947236     0.990294
# Project Score       0.837864     0.927296
# Final Exam          1.000000     0.971277
# Total Score         0.971277     1.000000

# %%
# data visulaization
import seaborn as sns
sns.heatmap(z,annot=True)
# Heatmap:is a corelation visual representation of the corelation
# it is a corelation matrix between multiple variables using 
#colors to indicate the strength and direct relationship between them
# annot enable it adds values inside your cell
# Out:
# <Axes: >

# %%
df.hist(figsize=(12,6),layout=(2,3))
# Out:
# array([[<Axes: title={'center': 'Grade'}>,
#         <Axes: title={'center': 'Test Score'}>,
#         <Axes: title={'center': 'Assignment Score'}>],
#        [<Axes: title={'center': 'Project Score'}>,
#         <Axes: title={'center': 'Final Exam'}>,
#         <Axes: title={'center': 'Total Score'}>]], dtype=object)

# %%
sns.pairplot(df)
# Out:
# C:\Users\GT-499\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
