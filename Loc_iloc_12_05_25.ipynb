# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\GT-499\Downloads\players_20 (1).csv")
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
row1=df.iloc[3]

# %%
row1
# Out:
# sofifa_id                                                200389
# player_url    https://sofifa.com/player/200389/jan-oblak/20/...
# short_name                                             J. Oblak
# long_name                                             Jan Oblak
# age                                                          26
#                                     ...
# lb                                                          NaN
# lcb                                                         NaN
# cb                                                          NaN
# rcb                                                         NaN
# rb                                                          NaN
# Name: 3, Length: 104, dtype: object

# %%
row2=df.loc[3]

# %%
row2
# Out:
# sofifa_id                                                200389
# player_url    https://sofifa.com/player/200389/jan-oblak/20/...
# short_name                                             J. Oblak
# long_name                                             Jan Oblak
# age                                                          26
#                                     ...
# lb                                                          NaN
# lcb                                                         NaN
# cb                                                          NaN
# rcb                                                         NaN
# rb                                                          NaN
# Name: 3, Length: 104, dtype: object

# %%
row1==row2
# Out:
# sofifa_id      True
# player_url     True
# short_name     True
# long_name      True
# age            True
#               ...
# lb            False
# lcb           False
# cb            False
# rcb           False
# rb            False
# Name: 3, Length: 104, dtype: bool

# %%
df.iloc[[2,5,6,8]]
# Out:
#    sofifa_id                                         player_url  \
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
#
#       short_name                      long_name  age         dob  height_cm  \
# 2      Neymar Jr  Neymar da Silva Santos Junior   27  26-06-1987        175
# 5   K. De Bruyne                Kevin De Bruyne   28  29-06-1987        181
# 6  M. ter Stegen          Marc-André ter Stegen   27  30-06-1987        187
# 8      L. Modrić                    Luka Modrić   33  02-07-1987        172
#
#    weight_kg nationality                 club  ...   lwb   ldm   cdm   rdm  \
# 2         68      Brazil  Paris Saint-Germain  ...  66+3  61+3  61+3  61+3
# 5         70     Belgium      Manchester City  ...  77+3  77+3  77+3  77+3
# ...

# %%
df.loc[[25,45,67,89]]
# Out:
#     sofifa_id                                         player_url  \
# 25     210257  https://sofifa.com/player/210257/ederson-santa...
# 45     164240  https://sofifa.com/player/164240/thiago-emilia...
# 67     184344  https://sofifa.com/player/184344/leonardo-bonu...
# 89     192505  https://sofifa.com/player/192505/romelu-lukaku...
#
#       short_name                  long_name  age         dob  height_cm  \
# 25       Ederson  Ederson Santana de Moraes   25  19-07-1987        188
# 45  Thiago Silva   Thiago Emiliano da Silva   34  08-08-1987        183
# 67    L. Bonucci           Leonardo Bonucci   32  30-08-1987        190
# 89     R. Lukaku              Romelu Lukaku   26  21-09-1987        190
#
#     weight_kg nationality                 club  ...   lwb   ldm   cdm   rdm  \
# 25         86      Brazil      Manchester City  ...   NaN   NaN   NaN   NaN
# 45         82      Brazil  Paris Saint-Germain  ...  77+3  82+3  82+3  82+3
# ...

# %%
df.iloc[2:5]
# Last index will not be read
# Last index is excluded in iloc
# Out:
#    sofifa_id                                         player_url short_name  \
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  Neymar Jr
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...   J. Oblak
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  E. Hazard
#
#                        long_name  age         dob  height_cm  weight_kg  \
# 2  Neymar da Silva Santos Junior   27  26-06-1987        175         68
# 3                      Jan Oblak   26  27-06-1987        188         87
# 4                    Eden Hazard   28  28-06-1987        175         74
#
#   nationality                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 2      Brazil  Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# 3    Slovenia      Atlético Madrid  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4     Belgium          Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3
#
#     lcb    cb   rcb    rb
# 2  46+3  46+3  46+3  61+3
# ...

# %%
df.loc[2:5]
# Out:
#    sofifa_id                                         player_url    short_name  \
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...     Neymar Jr
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...      J. Oblak
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...     E. Hazard
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...  K. De Bruyne
#
#                        long_name  age         dob  height_cm  weight_kg  \
# 2  Neymar da Silva Santos Junior   27  26-06-1987        175         68
# 3                      Jan Oblak   26  27-06-1987        188         87
# 4                    Eden Hazard   28  28-06-1987        175         74
# 5                Kevin De Bruyne   28  29-06-1987        181         70
#
#   nationality                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 2      Brazil  Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# ...

# %%
# Last index is included in loc
# loc is label based,iloc is index based
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
# string slicing is allowed
df.loc[:,['sofifa_id', 'player_url', 'short_name', 'long_name']]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
df.iloc[:,0:3]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name
# 0               L. Messi
# 1      Cristiano Ronaldo
# 2              Neymar Jr
# 3               J. Oblak
# ...

# %%
df.iloc[:,[0,1,2,3]]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
df.columns
df.loc[2:5,['long_name','age','nationality']]
# Out:
#                        long_name  age nationality
# 2  Neymar da Silva Santos Junior   27      Brazil
# 3                      Jan Oblak   26    Slovenia
# 4                    Eden Hazard   28     Belgium
# 5                Kevin De Bruyne   28     Belgium
