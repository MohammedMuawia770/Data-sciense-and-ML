# %%
#AGENDA
#DEPLOYMENT USING STREAMLIT
# Streamlit is a free
# open source python library
# that allows users to
#create and share custom
#web apps for data science and machine learning
#application
# Deploy,manage and share apps using community cloud platform
# Steps to deploy streamlit
# Activate your environment using command line
# Import streamlit as st
# write any python code using st.write
# run the streamlit application using python notebook
# !pip install streamlit

# %%
# %%writefile app.py
import streamlit as st
st.title("Excelr Solutions")
st.write("I love myself and datascience and machine learning")
# Out:
# Writing app.py

# %%
#Step3:
# !wget  -q -o - ipv4.canhanzip.com
# canhanzip allows us to buid domain into scripts to automatically determine
#what is your public IP address from any system of the earth

# %%
#Step4:
! streamlit run app.py & npx localtunnel --port 8501
# local tunnel allows us to easily web service on your local network
#machine
# Out:
# ...
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.145.125.37:8501
#
# ⠋⠙⠹⠸Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼your url is: https://grumpy-rivers-flash.loca.lt
