# %%
# Three logical operators:And,or and not
# The output of a logical operator is always boolean
# And(and)
x=4
print(x<5 and x>8)
# Out:
# False

# %%
# Not operator :Compliment of your input
not(x<5 and x>8)
# Out:
# True

# %%
#x=10,x=5,compliment output

# %%
# Or(or)
x=4
print(x<5 or x>8)
# Out:
# True

# %%
not(x<5 or x>8)
# Out:
# False

# %%
#try x=23

# %%
# ASSIGNMENT OPERATORS IN PYTHON ARE USED TO ASSIGN VALUES TO SAME VARIABLES
#(=),which assigns the values on the right to the variable on the left

# %%
x=5
y=x

# %%
print(x)
# Out:
# 5

# %%
print(y)
# Out:
# 5

# %%
#assignment operators
x=10
x+=5
print(x)
#+=,x=x+5,x=10+5
# Out:
# 15

# %%
x=10
x-=5
print(x)
# x=x-5,10-5
# Out:
# 5

# %%
#subtraction,multiplication,division,modulous,exponential
x=10
x*=5
print(x)
# x=x*5,10*5
# Out:
# 50

# %%
x=10
x/=5
print(x)
# x=x/5,10/5
# Out:
# 2.0

# %%
x=10
x%=5
print(x)
# x=x%5,1o modulous 5
# Out:
# 0

# %%
x=10
x**=5
print(x)
# x=x to the power of5,1ox10x10x10x10
# Out:
# 100000

# %%
x=10
x//=5
print(x)
# Out:
# 2

# %%
x=28
x//=10

# %%
x
# Out:
# 2

# %%
#
