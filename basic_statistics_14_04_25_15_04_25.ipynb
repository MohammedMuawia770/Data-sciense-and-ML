# %%
import statistics as st
y=[10,20,30,40,50]
x=st.mean(y)
x
# Out:
# 30

# %%
# Mean is the average of the given numbers,dataset
# Mean=sum of all the elements/Number of elements
# st is alias name
#10+20+30+40+50
#150/5

# %%
import statistics
x=[-11,-12,-45,60,78]
y=statistics.mean(x)
y
# Out:
# 14

# %%
# MEDIAN IS A MIDDLE VALUE  AFTER SORTING LIST
# sTEP1: ARRANGE IN ASCENDING AND DESCENDING
# .median
#10,20,30,50,60
x=[20,10,30,50,60]
import statistics as st
y=st.median(x)
y
# Out:
# 30

# %%
# Note :Variables cannot be keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=[20,10,30,50,60,70]
import statistics as st
y=st.median(x)
y
# Out:
# 40.0

# %%
# STANDARD DEVAITION and VARIANCE(MEASURE OF SPREAD,HOW YOU
#R DATAPOINTS VARIES WITH RESPECT TO MEAN)
#STDEV
# MEASURE OF SPREAD
# Standard devaition is measure of spread
# Large stanadard deviation indicates how the data is spread out
# Small standard deviation indicates how clsuters are claosely around mean
# standard deviation is square root of variance
# variance and stdev(inbuilt function)
# Out:
# 40.0

# %%
x=[20,10,30,50,60,70]
import statistics as st
y=st.variance(x)
y
# Out:
# 560

# %%
x=[20,10,30,50,60,70]
import statistics as st
y=st.stdev(x)
y
# Out:
# 23.664319132398465

# %%
import math
math.sqrt(560)
# Out:
# 23.664319132398465

# %%
# calculate mean,median,std ,variance
# -30,-23,56.7,90.0,78,9,89

# %%
# mode is a frequency
# MODE IS THE VALUE that often appears the  most often in set of data values
# Bimodal,Trimodal

# %%
d=20,10,20,34,45,67
import statistics as st
z=st.mode(d)
print(z)
# Out:
# 20

# %%
d=20,10,20,34,45,67,67
import statistics as st
z=st.mode(d)
print(z)
# Out:
# 20

# %%
d=20,10,20,34,45,67,67
import statistics as st
z=st.multimode(d)
print(z)
# Out:
# [20, 67]

# %%
d=20,10,20,34,45,67,67,67
import statistics as st
z=st.multimode(d)
print(z)
# Out:
# [67]

# %%
d=20,10,20,34,45,67,34,10
import statistics as st
z=st.multimode(d)
print(z)
# Out:
# [20, 10, 34]

# %%
d=20,10,20,34,45,67,34,10
import statistics as at
at.mode(d)
# Out:
# 20
