# %%
import pandas as pd
df=pd.read_csv("/content/tips (1).csv")
df
# use case :Number of smokers versus total bill plot a boxplot
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['total_bill'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78b9538db290>,
#   <matplotlib.lines.Line2D at 0x78b9538f9390>],
#  'caps': [<matplotlib.lines.Line2D at 0x78b9538f9d50>,
#   <matplotlib.lines.Line2D at 0x78b9538fa850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78b9544a3cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78b9538fb210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78b9538fbb10>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78b95386ac90>,
#   <matplotlib.lines.Line2D at 0x78b95386b6d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x78b95386bf10>,
#   <matplotlib.lines.Line2D at 0x78b9538748d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78b95386a350>],
#  'medians': [<matplotlib.lines.Line2D at 0x78b953875090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78b9538759d0>],
#  'means': []}

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
import seaborn as sns
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# number of smokers visiting restaurant and spending is more compared to nonsmokers
