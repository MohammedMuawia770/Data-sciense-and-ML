# %%
# # histogram is a visual representation of distribution of quantitive of data
# # Keywords(bin or bucket)
# # Frequency 
# # Numerical plot

# age_men=25,11,68,18,27,28,15,43,58,63,43,65,51,36,33,26,23,35,49,58
# age_women=14,6,2,2,4,15,11,18,1,7,2,1,3,4,10,22

# %%
import matplotlib.pyplot as plt

age_men=25,11,68,18,27,28,15,43,58,63,43,65,51,36,33,26,23,35,49,58
age_women=14,6,2,2,4,15,11,18,1,7,2,1,3,4,10,22,46,50,51
plt.xlabel('age of men')
plt.ylabel('age of women')
plt.title("histogram plot of age of man versus frequency")
plt.hist(age_men,bins=10,edgecolor='black')
# plt.hist(age_women ,bins=10,edgecolor='black')
plt.show()
