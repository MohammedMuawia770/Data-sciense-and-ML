# %%
# Decision Tree classifier is a supervised machine learning algorithm used for classification tasks
# start from the root node
#split the data
# entropy,gini
# repeat the process for each child node
import pandas as pd
df=pd.read_csv("/content/comedy_new.csv")
df
# Out:
#     Age  Exp  Rank  Nationality   GO
# 0    36   10     9           UK   NO
# 1    42   12     4          USA   NO
# 2    23    4     6            N   NO
# 3    52    4     4          USA   NO
# 4    43   21     8          USA  YES
# 5    44   14     5           UK   NO
# 6    66    3     7            N  YES
# 7    35   14     9           UK  YES
# 8    52   13     7            N  YES
# 9    35    5     9            N  YES
# 10   24    3     5          USA   NO
# 11   18    3     7           UK  YES
# 12   45    9     9           UK  YES

# %%
df.shape
# Out:
# (13, 5)

# %%
df.columns
# Out:
# Index(['Age', 'Exp', 'Rank', ' Nationality', 'GO'], dtype='object')

# %%
# # DICTIONARY(NLP,TEXT Processing:categorical to Numerical)
# d={'UK':0,'USA':1,'N':2}
# df[' Nationality'].map(d)
# d={'YES':1,'NO':0}
# df['GO'].map(d)
# print(df)
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df[' Nationality']=LE.fit_transform(df[' Nationality'])
df['GO']=LE.fit_transform(df['GO'])

df
# Out:
#     Age  Exp  Rank   Nationality  GO  G0
# 0    36   10     9             1   0   0
# 1    42   12     4             2   0   0
# 2    23    4     6             0   0   0
# 3    52    4     4             2   0   0
# 4    43   21     8             2   1   1
# 5    44   14     5             1   0   0
# 6    66    3     7             0   1   1
# 7    35   14     9             1   1   1
# 8    52   13     7             0   1   1
# 9    35    5     9             0   1   1
# 10   24    3     5             2   0   0
# 11   18    3     7             1   1   1
# 12   45    9     9             1   1   1

# %%
#

# %%
df.columns
# Out:
# Index(['Age', 'Exp', 'Rank', ' Nationality', 'GO', 'G0'], dtype='object')

# %%
features=['Age', 'Exp', 'Rank', ' Nationality']
x=df[features]
x
# Out:
#     Age  Exp  Rank   Nationality
# 0    36   10     9             1
# 1    42   12     4             2
# 2    23    4     6             0
# 3    52    4     4             2
# 4    43   21     8             2
# 5    44   14     5             1
# 6    66    3     7             0
# 7    35   14     9             1
# 8    52   13     7             0
# 9    35    5     9             0
# 10   24    3     5             2
# 11   18    3     7             1
# 12   45    9     9             1

# %%
y=df['GO']
y
# Out:
# 0      NO
# 1      NO
# 2      NO
# 3      NO
# 4     YES
# 5      NO
# 6     YES
# 7     YES
# 8     YES
# 9     YES
# 10     NO
# 11    YES
# 12    YES
# Name: GO, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree=dtree.fit(x,y)
tree.plot_tree(dtree,feature_names=features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-6caf5bf72a35> in <cell line: 0>()
#       2 dtree=DecisionTreeClassifier()
#       3 dtree=dtree.fit(x,y)
# ----> 4 tree.plot_tree(dtree,feature_names=features)
#
# NameError: name 'tree' is not defined
